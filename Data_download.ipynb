# %%
import os
import json
from kaggle.api.kaggle_api_extended import KaggleApi

# %%
with open('D:/MachineLearning/Kaggle/kaggle.json', 'r') as f:
    kaggle_config = json.load(f)

os.environ['KAGGLE_USERNAME'] = kaggle_config['username']
os.environ['KAGGLE_KEY'] = kaggle_config['key']

api = KaggleApi()
api.authenticate()

api.dataset_download_files("nelgiriyewithana/shoppersentiments", 
                           path='D:/MachineLearning/Kaggle/data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nelgiriyewithana/shoppersentiments

# %%
with open('D:/MachineLearning/Kaggle/kaggle.json', 'r') as f:
    kaggle_config = json.load(f)

os.environ['KAGGLE_USERNAME'] = kaggle_config['username']
os.environ['KAGGLE_KEY'] = kaggle_config['key']

api = KaggleApi()
api.authenticate()

api.dataset_download_files("nadyinky/sephora-products-and-skincare-reviews", 
                           path='D:/MachineLearning/Kaggle/data/Sephora', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nadyinky/sephora-products-and-skincare-reviews
